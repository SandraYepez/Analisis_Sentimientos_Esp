# %%
# %pip install pandas
# %pip install pymongo[srv]
# %pip install Twython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo[srv]
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 13.2 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 27.0 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.3.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Twython
#   Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from Twython) (2.27.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from Twython) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->Twython) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->Twython) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->Twython) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->Twython) (2022.12.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.4.0->Twython) (3.2.2)
# Installing collected packages: Twython
# Successfully installed Twython-3.9.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
Author: Dr. Roger Clotet
Ejemplo de importación de Social Media en Mongo DB

Importación de twits en una base de datos Mongo.


ANTES DE EJECUTAR ESTE SCRIPT, ES NECESARIO:
    1. Tener instalado Python 3.7 o superior
    2. Haber creado un archivo CSV que contenga las cuentas de twitter que se desean descargar.
    3. Tener instancia en la nube de MongoDB Atlas, MongoDB instalado en local o en un servidor propio.

EL CÓDIGO SE DIVIDO EN 7 PARTES
    1. Importación de los paquetes de python necesarios
    2. Importación de Twython y Twitter app key and access token
       - ES NECESARIO MODIFICAR ESTA SECCIÓN CON EL FIN DE CONSEGUIR QUE EL SCRIPT FUNCIONE
    3. Definición para leer datos de Twitter
    4. Configurar la base de datos Mongo y las colecciones
    5. Leer las cuentas de Twitter (y añadir a MongoDB si es posible)
    6. Bucle principal sobre el cual las cuentas de Twitter se añaden a la colección de cuentas en MongoDB
    7. Impresión del número de tweets en la base de datos por cuenta.

"""
###### PARTE 1: Importación de los paquetes de python necesarios  ######
#import sys
import time
import json
import pandas as pd
import pymongo
from twython import Twython #Necesario instalarlo la primera vez de forma aislada: pip install Twython
import timeit


###### PARTE 2: Importación de Twython y Twitter app key and access token
#      Información de las Key y Token disponible en la cuenta de Twitter Developer o la común compartida por el profesor
######

APP_KEY = 'Poner la API kEY' # API Key
APP_SECRET = 'Poner API Secret Key' # API Secret Key
OAUTH_TOKEN = 'Poner Access Token' # Access Token
OAUTH_TOKEN_SECRET = 'Poner Access Token Secret' # Access Token Secret

twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)



###### PARTE 3: Definición para leer datos de Twitter ######

def get_data_user_timeline_all_pages(kid, page):
    try:
        '''
        'count' especifica el número de tweets que se deben intentar recuperar, hasta un máximo de 200
 por solicitud distinta. El valor del conteo se considera mejor como un límite para
 el número de tweets que se devolverán porque se eliminó el contenido suspendido o eliminado
 después de que el recuento ha sido aplicado Incluimos retweets en el conteo, incluso si
 include_rts no se suministra. Se recomienda que siempre envíe include_rts = 1 cuando
 utilizando este método API.
        '''
        d = twitter.get_user_timeline(screen_name=kid, count="200", page=page, include_entities="true", include_rts="1")
    except Exception as e:
        print ("Error reading id %s, exception: %s" % (kid, e))
        return None
    return d

#Para visualizar los campos (keys del diccionario) introducidos
#    if len(d)>0:
#        print ("d.keys(): ", d[0].keys())


###### PARTE 4: Configurar la base de datos Mongo y las colecciones ######

#Establecimiento Conexión a MongoDB Atlas


# Datos de ejemplo, necesario modificar por vuestra instancia en MongoDB Atlas o local
dbStringConnection = "Poner String de Conexión"



dbName = 'Futbol_Colombiano'
dbCollectionA = 'twitter_Actividad_Cuentas_R'
dbCollectionT = 'tweets_Actividad_R'

client = pymongo.MongoClient(dbStringConnection)

# Definición de la base de datos MongoDB
db = client[dbName]

# Crea la colección accounts in la base de datos para los detalles de las cuentas de twitter
accounts = db[dbCollectionA]

# Crea un índice sobre la colección de cuentas para evitar la inserción de duplicados
db[dbCollectionA].create_index([('Twitter_handle', pymongo.ASCENDING)], unique=True)

# Muestra los índices sobre la colección accounts
#list(db.accounts.index_information())

#Muestra el número de cuentas en la colección accounts
#accounts.count_documents({})

# Crea la colleción donde se insertarán los tweets
tweets = db[dbCollectionT]

# Crea un índice de unicidad en la colección tweets para evitar duplicados
db[dbCollectionT].create_index([('id_str', pymongo.ASCENDING)], unique=True)

#Muestra los índices sobre la colección tweets
#list(db.tweets.index_information())

#Muestra el número de tweets en la tabla
#tweets.count_documents({})

#Para ver el listado de las bases de datos en MongoDB
#client.database_names()

#Para ver el listado de las colecciones en la base de datos 'MLB'
#db.collection_names()


###### PARTE 5: Leer las cuentas de Twitter (y añadir a MongoDB si es posible)

#Siempre trata de insertar las cuentas, si ya tenemos todas podemos cambiar a la otra versón que primero comprueba
#Substituir el fichero accountsEMBS.csv por el fichero csv propio con los datos de las cuentas de Twitter

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/futbolColombiano.csv', encoding='latin-1')

print ("Intentando insertar ", len(df), " cuentas de Twitter")

repetidas = 0
cuentasTwitter = json.loads(df.T.to_json()).values()
for cuenta in cuentasTwitter:
    try:
        accounts.insert_one(cuenta)
    except pymongo.errors.DuplicateKeyError as e:
        print (e, '\n')
        repetidas += 1
print ("Insertadas ", len(df)-repetidas, " cuentas de Twitter. " , repetidas, " cuentas repetidas.")

#records = json.loads(df.T.to_json()).values()
#try:
#    print(accounts.insert_many(records))
#except pymongo.errors.BulkWriteError:
#    print ('BulkWriteError\n');


# Alternativa, solo leer y cargar a MongoDB sí la colleción de cuentas es vacía
#if accounts.count_documents({}) < 1:
#    df = pd.read_csv('accountsEMBS.csv', encoding='latin-1')
#    records = json.loads(df.T.to_json()).values()
#    print ("No account data in MongoDB, attempting to insert", len(records), "records")
#    try:
#        accounts.insert_many(records)
#    except pymongo.errors.BulkWriteError:
#        print ('BulkWriteError\n');
        #pass
#else:
 #   print ("There are already", accounts.count_documents({}), "records in the *accounts* table")


# Listar documentos en la colección accounts
#list(accounts.find())[:1]

# Crea la lista de cuentas de twitter para descargar tweets
twitter_accounts = accounts.distinct('Twitter_handle')
#print len(twitter_accounts)
#twitter_accounts[:5]

###### PARTE 6: Bucle principal sobre el cual las cuentas de Twitter se añaden a la colección de cuentas en MongoDB   ######

start_time = timeit.default_timer()

starting_count = tweets.count_documents({})

#for s in twitter_accounts[:len(twitter_accounts)]:
for s in twitter_accounts[:len(twitter_accounts)]:
    #Fija el contador de duplicados para esta cuenta de twitter a cero
    duplicates = 0

    #Comprueba el ratio límite de llamadas por minuto en el API de twitter (900 peticiones/15-minutos)
    rate_limit = twitter.get_application_rate_limit_status()['resources']['statuses']['/statuses/user_timeline']['remaining']
    print ('\n', rate_limit, '# llamadas a la API restantes')

    #tweet_id = str(mentions.find_one( { "query_screen_name": s}, sort=[("id_str", 1)])["id_str"])
    print ('\nLeyendo tweets enviados por: ', s, '-- index: ', twitter_accounts.index(s))

    page = 1

    #Se pueden descargar 200 tweets por llamada y hasta 3.200 tweets totales, es decir, 16 páginas por cuenta
    while page < 11:
        print ("--- STARTING PAGE", page, '...llamadas a la API restantes estimadas: ', rate_limit)

        d = get_data_user_timeline_all_pages(s, page)
        if not d:
            print ("No hubo tweets devueltos........Desplazandose al siguiente ID")
            break
        if len(d)==0:    #Este registro es diferentes de las menciones y los ficheros DMS
            print ("No hubo tweets devueltos........Desplazandose al siguiente ID")
            break
        #if not d['statuses']:
        #    break


        #Decrementamos en 1 el contador rate_limit
        rate_limit -= 1
        print ('..........llamadas a la API restantes estimadas: ', rate_limit)


        ##### Escribimos los datos en MongoDB -- iteramos sobre cada tweet
        for entry in d:

            #Convertimos los datos de twitter para insertarlos en Mongo
            t = json.dumps(entry)
            #print 'type(t)', type(t)                   #<type 'str'>
            loaded_entry = json.loads(t)
            #print type(loaded_entry) , loaded_entry    #<type 'dict'>

            #Insertamos el tweet en la base de datos -- A menos que este ya existe
            try:
                 tweets.insert_one(loaded_entry)
            except pymongo.errors.DuplicateKeyError as e:
                print (e, '\n')
                duplicates += 1
                if duplicates>9:
                    break
                pass


        print ('--- PÁGINA FINALIZADA ', page, ' PARA ORGANIZAR ', s, "--", len(d), " TWEETS")

        #Si hay demasiados duplicados entonces saltamos a la siguietne cuenta
        if duplicates > 9:
            print ('\n********************Hay %s' % duplicates, 'duplicados....saltando al siguiente ID ********************\n')
            #continue
            break

        page += 1
        if page > 16:
            print ("NO SE ENCUENTRA AL FINAL DE LA PÁGINA 16")
            break

        # ESTE ES UN MÉTODO CRUDO QUE PONE EN UN CONTROL DE LÍMITE DE TASA API
        # EL LÍMITE DE VELOCIDAD PARA COMPROBAR CUÁNTAS SON LAS LLAMADAS DE API SON 180, LO QUE SIGNIFICA QUE NO PODEMOS
        if rate_limit < 5:
            print ('Se estiman menos de 5 llamadas API ... verifique y haga una pausa de 5 minutos si es necesario')
            rate_limit_check = twitter.get_application_rate_limit_status()['resources']['statuses']['/statuses/user_timeline']['remaining']
            print ('.......y el límite de ratio de acceso al API actual es: ', rate_limit_check)
            if rate_limit_check<5:
                print ('Quedan menos de 5 llamadas API ... pausando por 5 minutos')
                time.sleep(300) #PAUSA DE 300 SEGUNDOS
                rate_limit = twitter.get_application_rate_limit_status()['resources']['statuses']['/statuses/user_timeline']['remaining']
                print ('.......Este es el límite de ratio de acceso al API después de una pausa de 5 minutos: ', rate_limit)
                #si el rate_limit_check == 900:
                #    rate_limit = 900

    #if twitter.get_application_rate_limit_status()['resources']['search']['/search/tweets']['remaining']<5:
    if rate_limit < 5:
        print ('Quedan menos de 5 llamadas API estimadas ... pausando por 5 minutos...')
        time.sleep(300) #PAUSA POR 300 SEGUNDOS


elapsed = timeit.default_timer() - start_time
print ('# de minutos: ', elapsed/60)
print ("Número de nuevos tweets añadidos en esta ejecución: ", tweets.count_documents({}) - starting_count)
print ("Número de tweets actuales en la BD: ", tweets.count_documents({}), '\n', '\n')





###### PARTE 7: Impresión del número de tweets en la base de datos por cuenta. ######

for org in db.tweets.aggregate([
    {"$group":{"_id":"$screen_name", "sum":{"$sum":1}}}
    ]):
    print (org['_id'], org['sum'])
# Out:
# Intentando insertar  2  cuentas de Twitter
# Insertadas  2  cuentas de Twitter.  0  cuentas repetidas.
#
#  900 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  ABucaramanga -- index:  0
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  900
# ..........llamadas a la API restantes estimadas:  899
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652395423867215876" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652395423867215876" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652395423867215876'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652360738881560578" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652360738881560578" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652360738881560578'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652359184459890689" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652359184459890689" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652359184459890689'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650998326043525120" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650998326043525120" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650998326043525120'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650996601718992897" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650996601718992897" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650996601718992897'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650996067180183552" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650996067180183552" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650996067180183552'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650995241778917376" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650995241778917376" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650995241778917376'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650994533910315016" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650994533910315016" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650994533910315016'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650993779334160385" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650993779334160385" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650993779334160385'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650993160435163136" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650993160435163136" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650993160435163136'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  ABucaramanga -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  899 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  APetrolera -- index:  1
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  899
# ..........llamadas a la API restantes estimadas:  898
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652389007743959048" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652389007743959048" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652389007743959048'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652367554847858693" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652367554847858693" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652367554847858693'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652336173975584770" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652336173975584770" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652336173975584770'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652298190572453889" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652298190572453889" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652298190572453889'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652120276384071681" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652120276384071681" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652120276384071681'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652031100850511872" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652031100850511872" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652031100850511872'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652031089878114311" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652031089878114311" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652031089878114311'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652031072912146432" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652031072912146432" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652031072912146432'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651972916324495361" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651972916324495361" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651972916324495361'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651972827984044043" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651972827984044043" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651972827984044043'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  APetrolera -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  898 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  AsoDeporCali -- index:  2
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  898
# ..........llamadas a la API restantes estimadas:  897
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652434221288308737" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652434221288308737" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652434221288308737'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652416421417107457" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652416421417107457" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652416421417107457'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652401779273875457" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652401779273875457" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652401779273875457'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652391670070083585" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652391670070083585" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652391670070083585'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652391658175053825" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652391658175053825" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652391658175053825'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652363633375035392" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652363633375035392" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652363633375035392'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652101989822595075" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652101989822595075" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652101989822595075'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652101946268893185" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652101946268893185" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652101946268893185'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652085456836734977" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652085456836734977" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652085456836734977'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651813913686679553" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651813913686679553" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651813913686679553'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  AsoDeporCali -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  897 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  AtlJunior -- index:  3
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  897
# ..........llamadas a la API restantes estimadas:  896
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650915453189996573" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650915453189996573" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650915453189996573'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1646860378834362368" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1646860378834362368" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1646860378834362368'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1641585853905395715" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1641585853905395715" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1641585853905395715'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1638528395272245248" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1638528395272245248" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1638528395272245248'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1630782156078301184" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1630782156078301184" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1630782156078301184'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1629154631635857409" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1629154631635857409" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1629154631635857409'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627863046285656064" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627863046285656064" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1627863046285656064'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627336282513743872" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627336282513743872" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1627336282513743872'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627160186132496386" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627160186132496386" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1627160186132496386'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627155294340931584" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1627155294340931584" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1627155294340931584'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  AtlJunior -- 199  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  896 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  BlogVerdolaga -- index:  4
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  896
# ..........llamadas a la API restantes estimadas:  895
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652327553216962566" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652327553216962566" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652327553216962566'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652095895117209601" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652095895117209601" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652095895117209601'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652058889267953667" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652058889267953667" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652058889267953667'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651757924677459968" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651757924677459968" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651757924677459968'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651674225000734720" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651674225000734720" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651674225000734720'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651674211239313411" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651674211239313411" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651674211239313411'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651633670724231183" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651633670724231183" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651633670724231183'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651633487693193229" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651633487693193229" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651633487693193229'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651632553227427854" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651632553227427854" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651632553227427854'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651632220161945601" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651632220161945601" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651632220161945601'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  BlogVerdolaga -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  895 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  ClubLlanerosFC -- index:  5
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  895
# ..........llamadas a la API restantes estimadas:  894
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  ClubLlanerosFC -- 192  TWEETS
# --- STARTING PAGE 2 ...llamadas a la API restantes estimadas:  894
# ..........llamadas a la API restantes estimadas:  893
# --- PÁGINA FINALIZADA  2  PARA ORGANIZAR  ClubLlanerosFC -- 196  TWEETS
# --- STARTING PAGE 3 ...llamadas a la API restantes estimadas:  893
# ..........llamadas a la API restantes estimadas:  892
# --- PÁGINA FINALIZADA  3  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 4 ...llamadas a la API restantes estimadas:  892
# ..........llamadas a la API restantes estimadas:  891
# --- PÁGINA FINALIZADA  4  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 5 ...llamadas a la API restantes estimadas:  891
# ..........llamadas a la API restantes estimadas:  890
# --- PÁGINA FINALIZADA  5  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 6 ...llamadas a la API restantes estimadas:  890
# ..........llamadas a la API restantes estimadas:  889
# --- PÁGINA FINALIZADA  6  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 7 ...llamadas a la API restantes estimadas:  889
# ..........llamadas a la API restantes estimadas:  888
# --- PÁGINA FINALIZADA  7  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 8 ...llamadas a la API restantes estimadas:  888
# ..........llamadas a la API restantes estimadas:  887
# --- PÁGINA FINALIZADA  8  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 9 ...llamadas a la API restantes estimadas:  887
# ..........llamadas a la API restantes estimadas:  886
# --- PÁGINA FINALIZADA  9  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
# --- STARTING PAGE 10 ...llamadas a la API restantes estimadas:  886
# ..........llamadas a la API restantes estimadas:  885
# --- PÁGINA FINALIZADA  10  PARA ORGANIZAR  ClubLlanerosFC -- 200  TWEETS
#
#  885 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  Cucutaoficial -- index:  6
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  885
# ..........llamadas a la API restantes estimadas:  884
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652150310352109569" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652150310352109569" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652150310352109569'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652139975809331201" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652139975809331201" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652139975809331201'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652137684607942658" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652137684607942658" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652137684607942658'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652136698157883393" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652136698157883393" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652136698157883393'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652133257410904064" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652133257410904064" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652133257410904064'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652128318521589760" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652128318521589760" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652128318521589760'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652126871998349312" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652126871998349312" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652126871998349312'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652126112959348739" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652126112959348739" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652126112959348739'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652123651733348352" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652123651733348352" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652123651733348352'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652120491417559045" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652120491417559045" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652120491417559045'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  Cucutaoficial -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  884 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  DIM_Oficial -- index:  7
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  884
# ..........llamadas a la API restantes estimadas:  883
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652436704903479298" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652436704903479298" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652436704903479298'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652430267921977344" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652430267921977344" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652430267921977344'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423681023393792" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423681023393792" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652423681023393792'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652415913298108417" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652415913298108417" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652415913298108417'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652398984407797761" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652398984407797761" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652398984407797761'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652379640667729920" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652379640667729920" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652379640667729920'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652356063004446720" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652356063004446720" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652356063004446720'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652339930700435456" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652339930700435456" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652339930700435456'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652328913274654725" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652328913274654725" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652328913274654725'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652296683823443969" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652296683823443969" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652296683823443969'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  DIM_Oficial -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  883 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  DeporPasto -- index:  8
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  883
# ..........llamadas a la API restantes estimadas:  882
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652433435049246721" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652433435049246721" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652433435049246721'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652432972438556674" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652432972438556674" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652432972438556674'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652431547197259776" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652431547197259776" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652431547197259776'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652430126028603393" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652430126028603393" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652430126028603393'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652428756928045057" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652428756928045057" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652428756928045057'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652427686227202050" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652427686227202050" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652427686227202050'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426491722883077" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426491722883077" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652426491722883077'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652425057665204227" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652425057665204227" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652425057665204227'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652424363063365635" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652424363063365635" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652424363063365635'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423219045883905" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423219045883905" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652423219045883905'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  DeporPasto -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  882 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  DeporPereira -- index:  9
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  882
# ..........llamadas a la API restantes estimadas:  881
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651734033527717892" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651734033527717892" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651734033527717892'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651688674369630209" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651688674369630209" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651688674369630209'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650965630319751168" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650965630319751168" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650965630319751168'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650698663599955968" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650698663599955968" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650698663599955968'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650697064332886020" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650697064332886020" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650697064332886020'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650633993434324993" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1650633993434324993" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1650633993434324993'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648755679086235648" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648755679086235648" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1648755679086235648'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648528094981128193" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648528094981128193" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1648528094981128193'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648522403902017539" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648522403902017539" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1648522403902017539'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648511904451825664" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1648511904451825664" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1648511904451825664'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  DeporPereira -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  881 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  Dimayor -- index:  10
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  881
# ..........llamadas a la API restantes estimadas:  880
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438801313144832" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438801313144832" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652438801313144832'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438788931477505" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438788931477505" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652438788931477505'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438769667043332" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438769667043332" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652438769667043332'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652433221580206082" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652433221580206082" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652433221580206082'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423857733550083" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423857733550083" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652423857733550083'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423181771079681" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423181771079681" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652423181771079681'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652421944917065730" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652421944917065730" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652421944917065730'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652420330617556993" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652420330617556993" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652420330617556993'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652418074186862593" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652418074186862593" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652418074186862593'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652417252048732160" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652417252048732160" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652417252048732160'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  Dimayor -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  880 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  EnvigadoFC -- index:  11
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  880
# ..........llamadas a la API restantes estimadas:  879
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652439011674259456" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652439011674259456" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652439011674259456'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438531606757376" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438531606757376" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652438531606757376'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652381619645292549" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652381619645292549" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652381619645292549'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652381282242895884" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652381282242895884" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652381282242895884'}}
#
# ...
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652427104791977985" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652427104791977985" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652427104791977985'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426699764637700" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426699764637700" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652426699764637700'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426484898750464" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426484898750464" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652426484898750464'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426158007365638" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426158007365638" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652426158007365638'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652425757451272192" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652425757451272192" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652425757451272192'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  SantaFe -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  864 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  UnionMagdalena -- index:  18
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  864
# ..........llamadas a la API restantes estimadas:  863
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438911702953984" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652438911702953984" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652438911702953984'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652430335773122562" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652430335773122562" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652430335773122562'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426075182333953" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652426075182333953" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652426075182333953'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652425553448689664" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652425553448689664" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652425553448689664'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423296355377153" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652423296355377153" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652423296355377153'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652422404214341632" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652422404214341632" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652422404214341632'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652422102027317257" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652422102027317257" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652422102027317257'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652421289108205572" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652421289108205572" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652421289108205572'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652420835498393610" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652420835498393610" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652420835498393610'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652420620552896514" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652420620552896514" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652420620552896514'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  UnionMagdalena -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  863 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  ligapostobon -- index:  19
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  863
# Error reading id ligapostobon, exception: Twitter API returned a 401 (Unauthorized), An error occurred processing your request.
# No hubo tweets devueltos........Desplazandose al siguiente ID
#
#  862 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  nacionaloficial -- index:  20
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  862
# ..........llamadas a la API restantes estimadas:  861
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652437625226108933" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652437625226108933" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652437625226108933'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652342114636709889" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652342114636709889" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652342114636709889'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652281855612272640" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652281855612272640" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652281855612272640'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652175955916382208" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652175955916382208" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652175955916382208'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652070459284783104" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652070459284783104" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652070459284783104'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652055311501459457" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652055311501459457" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652055311501459457'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652010166412365827" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652010166412365827" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652010166412365827'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651978665998139393" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651978665998139393" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651978665998139393'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651722900288708617" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651722900288708617" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651722900288708617'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651662751096250391" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651662751096250391" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651662751096250391'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  nacionaloficial -- 197  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  861 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  oncecaldas -- index:  21
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  861
# ..........llamadas a la API restantes estimadas:  860
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652381032270774277" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652381032270774277" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652381032270774277'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652340299065180160" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652340299065180160" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652340299065180160'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652038646633996297" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1652038646633996297" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1652038646633996297'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651685755331178531" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651685755331178531" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651685755331178531'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651329051770986496" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651329051770986496" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651329051770986496'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651324821471461377" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651324821471461377" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651324821471461377'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651324531401715715" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651324531401715715" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651324531401715715'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651322228804288513" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651322228804288513" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651322228804288513'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651322083387817987" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651322083387817987" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651322083387817987'}}
#
# E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651316225975132166" }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: Futbol_Colombiano.tweets_Actividad_R index: id_str_1 dup key: { id_str: "1651316225975132166" }', 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1651316225975132166'}}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  oncecaldas -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
# # de minutos:  12.357096774683331
# Número de nuevos tweets añadidos en esta ejecución:  4117
# Número de tweets actuales en la BD:  42259
