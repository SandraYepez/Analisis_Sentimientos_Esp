# %%
# !pip install pymongo

# %%
# Biblioteca para crear barrar de procegro
# !pip install tqdm

# %%
# !pip install --upgrade tqdm
# !pip install --upgrade jupyter

# %%
# !pip install unidecode

# %%
# !pip install spacy

# %%
# Descargamos el modelo del lenguaje para el español
# !python -m spacy download es_core_news_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.9 MB 330.3 kB/s eta 0:00:39
#      --------------------------------------- 0.1/12.9 MB 525.1 kB/s eta 0:00:25
#      --------------------------------------- 0.1/12.9 MB 751.6 kB/s eta 0:00:18
#       --------------------------------------- 0.2/12.9 MB 1.3 MB/s eta 0:00:11
#       --------------------------------------- 0.3/12.9 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.4/12.9 MB 1.4 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/12.9 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/12.9 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.6/12.9 MB 1.5 MB/s eta 0:00:08
#      -- ------------------------------------- 0.7/12.9 MB 1.6 MB/s eta 0:00:08
#      -- ------------------------------------- 0.9/12.9 MB 1.7 MB/s eta 0:00:07
# ...

# %%
import os
import re
import pymongo
from unidecode import unidecode
from pymongo import MongoClient
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import pandas as pd
import time
import spacy
import numpy as np

# %%
num_cores = os.cpu_count()
print (f"Número de nucleos de CPU disponibles {num_cores}")
# Out:
# Número de nucleos de CPU disponibles 20

# %%
# Definir la función para limpiar el texto
def limpiar_texto(text):
    text = text.lower()
    text = unidecode(text) # Reemplaza los caracteres diacríticos en el texto por sus equivalentes no diacríticos
    text = re.sub(r"@[^\s]+", "", text)  # Menciones de Usuarios con Carcateres especiales
    text = re.sub(r"#", "", text) # Hashtag
    text = re.sub(r"^((https?://(www\.)?)|\www\.)\w{3,}\.[a-z]{2,3}$", "", text) # URL
    text = re.sub(r"https?://\S+|www\.\S+|t\.co/[A-Za-z0-9]+", "", text) # URL cortas de Twitter
    text = re.sub(r"[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U0001FB00-\U0001FBFF\U0001FC00-\U0001FCFF\U0001FD00-\U0001FDFF\U0001FE00-\U0001FEFF\U0001FF00-\U0001FFFF\U00002600-\U000026FF\U00002700-\U000027BF\U0001F004-\U0001F0CF\U0001F170-\U0001F251\U0001F004-\U0001F0CF\U0001F300-\U0001F5FF\U0001F600-\U0001F64F\U0001F650-\U0001F67F\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U0001FB00-\U0001FBFF\U0001FC00-\U0001FCFF\U0001FD00-\U0001FDFF\U0001FE00-\U0001FEFF\U0001FF00-\U0001FFFF\U00002600-\U000026FF\U00002700-\U000027BF\U0001F004-\U0001F0CF\U0001F170-\U0001F251]", "", text)
    text = re.sub(r"\$\d+(?:,\d{3})*(?:\.\d+?)", "", text) # Valores de Dinero, tiene en cuenta el símbolo $ y la separación del dígito ya sea por "," o "."
    text = re.sub(r"((\d)+/+(\d+[a-zA-Z]))", "", text) # Número/NúmeroLetra 173/2022c
    text = re.sub(r"\b\d+(?:\.\d+)?\b", "", text) # Números enteros y decimales
    #text = re.sub(r"^rt @([\w\-]+):", "", text) # Retweets de Usuarios
    text = re.sub(r"\d{1,2}:\d{2}([ap]m)?", "", text)  # Elimina horas como 12:34, 12:34pm, 12:34 am
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text) # Caracteres especiales
    text = re.sub(r"\b\d+\s?[A-Za-z]+\b", "", text) # números seguidos de letras
    text = re.sub(r'^rt\s*:?+', '', text) # Retweets de Usuarios

    return text

# %%
# Configuración de MongoDB
client = MongoClient('mongodb+srv://sandra_yepes:Db2fiaq07tl9PbsA@mbid01.hsejbkh.mongodb.net/test')

# Lista de bases de datos que deseas procesar
databases_to_process = ["Cantantes_Colombianos", "Deportistas_Colombianos", "Empresas_Colombianas",
                        "Famosos", "Futbol_Colombiano", "Instituciones_del_Estado_Colombiano",
                        "Medios_Informaticos", "Periodistas", "Politicos_Colombianos", "Universidades_Colombianas"]

# Función para procesar un lote de tweets
def process_tweet_batch(database_name):
    try:
        # Crear una conexión a la base de datos MongoDB dentro de esta función
        database = client[database_name]

        # Verificar si la colección "tweets_Actividad_R" existe en la base de datos actual
        if "tweets_Actividad_R" not in database.list_collection_names():
            return []  # Devolver una lista vacía si la colección no existe

        tweets_collection = database["tweets_Actividad_R"]

        skip = 0
        data = []  # Lista para almacenar los datos

        # Antes del bucle, obtén el número total de documentos
        total_tweets = tweets_collection.count_documents({})

        # Inicializar la barra de progreso para esta base de datos
        with tqdm(total=total_tweets, position=0, desc=f"Procesando '{database_name}'") as pbar:
            while True:
                # Consulta la colección de tweets con límite y salto (skip)
                tweets = tweets_collection.find().skip(skip).limit(100)
                
                # Itera sobre los tweets en el lote actual
                for tweet in tweets:
                    # Procesa cada tweet
                    tweet_text = tweet["text"]
                    nombre_usuario = tweet["user"]["name"]

                    # Aquí puedes realizar el procesamiento necesario
                    texto_limpio = limpiar_texto(tweet_text)
                    
                    # Agrega los datos procesados a la lista
                    data.append({'Nombre BD': database_name, 'Nombre Usuario': nombre_usuario, 'Tweet': tweet_text, 'Tweet Limpio': texto_limpio})
                    
                    # Actualiza la barra de progreso de esta base de datos
                    pbar.update(1)

                skip += 100

                # Verifica si se ha alcanzado el final de la colección
                if skip >= total_tweets:
                    break

        return data

    except Exception as e:
        # Manejar cualquier excepción que pueda ocurrir durante el procesamiento
        print(f"Error en la base de datos '{database_name}': {str(e)}")
        return []

if __name__ == "__main__":
    data = []  # Lista para almacenar los datos

    # Medir el tiempo de inicio
    start_time = time.time()

    # Iniciar el proceso en paralelo con ThreadPoolExecutor
    num_threads = min(4, len(databases_to_process))
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        # Utiliza executor.map para aplicar la función process_tweet_batch a las bases de datos en paralelo
        results = list(executor.map(process_tweet_batch, databases_to_process))

    # Combinar resultados en una sola lista de datos
    for result in results:
        data.extend(result)

    # Medir el tiempo de finalización
    end_time = time.time()

    # Calcular el tiempo total de ejecución
    total_time = end_time - start_time

    # Verifica si se recopilaron datos
    if data:
        print("Datos recopilados:")
        df = pd.DataFrame(data)  # Crea un DataFrame a partir de la lista de datos

        # Muestra el DataFrame
        print(df)

        # Guarda el DataFrame en un archivo CSV
        df.to_csv("tweets_preprocesados_BD.csv", index=False)
    else:
        print("No se recopilaron datos de las bases de datos seleccionadas.")

    # Muestra el tiempo total de ejecución
    print(f"Tiempo total de ejecución: {total_time} segundos")
# Out:
# ...
# Procesando 'Politicos_Colombianos': 100%|███████████████████████████████████████| 46733/46733 [05:13<00:00, 149.26it/s]
# Datos recopilados:
#                         Nombre BD Nombre Usuario  \
# 0           Cantantes_Colombianos         Camilo
# 1           Cantantes_Colombianos         Camilo
# 2           Cantantes_Colombianos         Camilo
# 3           Cantantes_Colombianos         Camilo
# 4           Cantantes_Colombianos         Camilo
# ...                           ...            ...
# 454388  Universidades_Colombianas            UPB
# 454389  Universidades_Colombianas            UPB
# 454390  Universidades_Colombianas            UPB
# 454391  Universidades_Colombianas            UPB
# 454392  Universidades_Colombianas            UPB
#
#                                                     Tweet  \
# 0       Gallo pinto en Costa Rica... y otras maneras d...
# 1       RT @rincondelatribu: La Tribu tiene casa, un h...
# ...

# %%
df.head(200)
# Out:
#                  Nombre BD Nombre Usuario  \
# 0    Cantantes_Colombianos         Camilo
# 1    Cantantes_Colombianos         Camilo
# 2    Cantantes_Colombianos         Camilo
# 3    Cantantes_Colombianos         Camilo
# 4    Cantantes_Colombianos         Camilo
# ..                     ...            ...
# 195  Cantantes_Colombianos         Camilo
# 196  Cantantes_Colombianos         Camilo
# 197  Cantantes_Colombianos         Camilo
# 198  Cantantes_Colombianos         Camilo
# 199  Cantantes_Colombianos         Camilo
#
#                                                  Tweet  \
# 0    Gallo pinto en Costa Rica... y otras maneras d...
# 1    RT @rincondelatribu: La Tribu tiene casa, un h...
# 2    Contando los días!! Ya quiero iiiiiiirrrrrr 🇧🇷...
# 3    En el aeropuerto en Buenos Aires por salir a c...
# 4    Recorriendo el mundo con mi esposa y mi hija h...
# ..                                                 ...
# 195  El 15 de Noviembre voy a estar en vivo en mi c...
# ...

# %%
# Leemos los dataframes
tweets = pd.read_csv('tweets_preprocesados_BD.csv',sep=',')

# %%
tweets.head(200)
# Out:
#                  Nombre BD Nombre Usuario  \
# 0    Cantantes_Colombianos         Camilo
# 1    Cantantes_Colombianos         Camilo
# 2    Cantantes_Colombianos         Camilo
# 3    Cantantes_Colombianos         Camilo
# 4    Cantantes_Colombianos         Camilo
# ..                     ...            ...
# 195  Cantantes_Colombianos         Camilo
# 196  Cantantes_Colombianos         Camilo
# 197  Cantantes_Colombianos         Camilo
# 198  Cantantes_Colombianos         Camilo
# 199  Cantantes_Colombianos         Camilo
#
#                                                  Tweet  \
# 0    Gallo pinto en Costa Rica... y otras maneras d...
# 1    RT @rincondelatribu: La Tribu tiene casa, un h...
# 2    Contando los días!! Ya quiero iiiiiiirrrrrr 🇧🇷...
# 3    En el aeropuerto en Buenos Aires por salir a c...
# 4    Recorriendo el mundo con mi esposa y mi hija h...
# ..                                                 ...
# 195  El 15 de Noviembre voy a estar en vivo en mi c...
# ...

# %%
tweets.shape
# Out:
# (454393, 4)

# %%
# Verificar las celdas nulas del Dataframe creado
valores_nulos = tweets.isna()
print(valores_nulos)
# Out:
#         Nombre BD  Nombre Usuario  Tweet  Tweet Limpio
# 0           False           False  False         False
# 1           False           False  False         False
# 2           False           False  False         False
# 3           False           False  False         False
# 4           False           False  False         False
# ...           ...             ...    ...           ...
# 454388      False           False  False         False
# 454389      False           False  False         False
# 454390      False           False  False         False
# 454391      False           False  False         False
# 454392      False           False  False         False
#
# [454393 rows x 4 columns]

# %%
# Contar los valores nulos por columna
conteo_nulos_columna = valores_nulos.sum()
print(conteo_nulos_columna)
# Out:
# Nombre BD            0
# Nombre Usuario       0
# Tweet                0
# Tweet Limpio      2889
# dtype: int64

# %%
tweets = tweets.dropna()

# %%
print(conteo_nulos_columna)
# Out:
# Nombre BD         0
# Nombre Usuario    0
# Tweet             0
# Tweet Limpio      0
# dtype: int64

# %%
tweets.shape
# Out:
# (451504, 4)

# %%
tweets.head()
# Out:
#                Nombre BD Nombre Usuario  \
# 0  Cantantes_Colombianos         Camilo
# 1  Cantantes_Colombianos         Camilo
# 2  Cantantes_Colombianos         Camilo
# 3  Cantantes_Colombianos         Camilo
# 4  Cantantes_Colombianos         Camilo
#
#                                                Tweet  \
# 0  Gallo pinto en Costa Rica... y otras maneras d...
# 1  RT @rincondelatribu: La Tribu tiene casa, un h...
# 2  Contando los días!! Ya quiero iiiiiiirrrrrr 🇧🇷...
# 3  En el aeropuerto en Buenos Aires por salir a c...
# 4  Recorriendo el mundo con mi esposa y mi hija h...
#
#                                         Tweet Limpio
# 0  gallo pinto en costa rica y otras maneras de d...
# 1            la tribu tiene casa un hogar es aqui \n
# 2        contando los dias ya quiero iiiiiiirrrrrr
# 3  en el aeropuerto en buenos aires por salir a c...
# 4  recorriendo el mundo con mi esposa y mi hija h...

# %% [markdown]
# # Detectar el idioma del Dataframe
# Detectar el idioma utilizando spaCy, usando el modelo "es_core_news_sm"
# Utilizo spaCy para analizar el texto en busca del idioma español, si el idioma es español, la fila se conserva en el DataFrame. De lo contrario, se excluye. SpaCy tienen un buen rendimiento en la detección del idioma

# %%
# Cargar el modelo de lenguaje para el español
nlp = spacy.load("es_core_news_sm")

# Función para detectar el idioma de un texto utilizando spaCy
def detect_language_spacy(text):
    try:
        doc = nlp(text)
        return doc.lang_
    except:
        return None

# Aplicar la función para detectar el idioma a la columna "Tweet Limpio"
tweets['Idioma'] = tweets['Tweet Limpio'].apply(detect_language_spacy)

# Filtrar solo las filas con textos en español
tweets = tweets[tweets['Idioma'] == 'es']

# Eliminar la columna "Idioma" si ya no la necesitas
tweets = tweets.drop(columns=['Idioma'])

# %%
tweets.shape
# Out:
# (451504, 4)

# %%
tweets.head(200)
# Out:
#                  Nombre BD Nombre Usuario  \
# 0    Cantantes_Colombianos         Camilo
# 1    Cantantes_Colombianos         Camilo
# 2    Cantantes_Colombianos         Camilo
# 3    Cantantes_Colombianos         Camilo
# 4    Cantantes_Colombianos         Camilo
# ..                     ...            ...
# 196  Cantantes_Colombianos         Camilo
# 197  Cantantes_Colombianos         Camilo
# 198  Cantantes_Colombianos         Camilo
# 199  Cantantes_Colombianos         Camilo
# 200  Cantantes_Colombianos         Camilo
#
#                                                  Tweet  \
# 0    Gallo pinto en Costa Rica... y otras maneras d...
# 1    RT @rincondelatribu: La Tribu tiene casa, un h...
# 2    Contando los días!! Ya quiero iiiiiiirrrrrr 🇧🇷...
# 3    En el aeropuerto en Buenos Aires por salir a c...
# 4    Recorriendo el mundo con mi esposa y mi hija h...
# ..                                                 ...
# 196  Momentos favoritos…\nMe pongo en perspectiva y...
# ...

# %%
# Limpiar los valores en la columna "Tweet Limpio" eliminando espacios en blanco adicionales
tweets['Tweet Limpio'] = tweets['Tweet Limpio'].str.strip()

# Reemplazar celdas en blanco (que ahora están limpias) por valores NaN
tweets.replace('', np.nan, inplace=True)

# Eliminar filas con valores NaN en la columna "Tweet Limpio"
tweets.dropna(subset=['Tweet Limpio'], inplace=True)

# %%
# Guarda el DataFrame en un archivo CSV
tweets.to_csv("tweets_limpios_esp_vacios2.csv", index=False)
